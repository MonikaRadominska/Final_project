# %% [markdown]
# ## Import libraries

# %%
import pandas as pd

# %% [markdown]
# ## Import data from IUCN's Red List

# %%
# start loading and exploring data 

df_redlist = pd.read_csv('Data/assessments.csv')

# %%
df_redlist
# Out:
#        assessmentId  internalTaxonId           scientificName  \
# 0            495630            10030        Hexanchus griseus
# 1            495907            10041      Heosemys annandalii
# 2            497499        132523146         Hubbsina turneri
# 3            497550            10267  Hungerfordia pelewensis
# 4            498476            10769      Ictalurus mexicanus
# ...             ...              ...                      ...
# 23315     222904443             4224  Cercopithecus nictitans
# 23316     222944655           136366              Sapajus cay
# 23317     222944989         70330181    Plecturocebus vieirai
# 23318     222945240        210363264          Mico schneideri
# 23319     223031019        181008073       Loxodonta africana
#
#              redlistCategory                     redlistCriteria  \
# 0            Near Threatened                                A2bd
# 1      Critically Endangered                            A2cd+4cd
# ...

# %%
df_redlist.columns
# Out:
# Index(['assessmentId', 'internalTaxonId', 'scientificName', 'redlistCategory',
#        'redlistCriteria', 'yearPublished', 'assessmentDate', 'criteriaVersion',
#        'language', 'rationale', 'habitat', 'threats', 'population',
#        'populationTrend', 'range', 'useTrade', 'systems',
#        'conservationActions', 'realm', 'yearLastSeen', 'possiblyExtinct',
#        'possiblyExtinctInTheWild', 'scopes'],
#       dtype='object')

# %%
df_redlist['redlistCategory']
# Out:
# 0              Near Threatened
# 1        Critically Endangered
# 2        Critically Endangered
# 3                   Endangered
# 4                   Vulnerable
#                  ...
# 23315          Near Threatened
# 23316               Vulnerable
# 23317    Critically Endangered
# 23318               Endangered
# 23319               Endangered
# Name: redlistCategory, Length: 23320, dtype: object

# %%
df_redlist['redlistCategory']

# %%
df_redlist['realm']
# Out:
# 0                 NaN
# 1         Indomalayan
# 2         Neotropical
# 3            Oceanian
# 4         Neotropical
#              ...
# 23315    Afrotropical
# 23316     Neotropical
# 23317     Neotropical
# 23318     Neotropical
# 23319    Afrotropical
# Name: realm, Length: 23320, dtype: object

# %%
df_redlist['populationTrend']
# Out:
# 0        Decreasing
# 1        Decreasing
# 2        Decreasing
# 3           Unknown
# 4           Unknown
#             ...
# 23315    Decreasing
# 23316    Decreasing
# 23317    Decreasing
# 23318    Decreasing
# 23319    Decreasing
# Name: populationTrend, Length: 23320, dtype: object

# %%
df_redlist['realm'].isna().sum()
# Out:
# 1329

# %%
df_redlist

# %%
df_taxom = pd.read_csv('Data/taxonomy.csv')

# %%
df_taxom
# Out:
#        internalTaxonId           scientificName kingdomName phylumName  \
# 0                10030        Hexanchus griseus    ANIMALIA   CHORDATA
# 1                10041      Heosemys annandalii    ANIMALIA   CHORDATA
# 2            132523146         Hubbsina turneri    ANIMALIA   CHORDATA
# 3                10267  Hungerfordia pelewensis    ANIMALIA   MOLLUSCA
# 4                10769      Ictalurus mexicanus    ANIMALIA   CHORDATA
# ...                ...                      ...         ...        ...
# 23315             4224  Cercopithecus nictitans    ANIMALIA   CHORDATA
# 23316           136366              Sapajus cay    ANIMALIA   CHORDATA
# 23317         70330181    Plecturocebus vieirai    ANIMALIA   CHORDATA
# 23318        210363264          Mico schneideri    ANIMALIA   CHORDATA
# 23319        181008073       Loxodonta africana    ANIMALIA   CHORDATA
#
#             className           orderName       familyName      genusName  \
# ...

# %%
df_taxom.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23320 entries, 0 to 23319
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   internalTaxonId    23320 non-null  int64
#  1   scientificName     23320 non-null  object
#  2   kingdomName        23320 non-null  object
#  3   phylumName         23320 non-null  object
#  4   className          23320 non-null  object
#  5   orderName          23320 non-null  object
#  6   familyName         23320 non-null  object
#  7   genusName          23320 non-null  object
#  8   speciesName        23319 non-null  object
#  9   infraType          0 non-null      float64
#  10  infraName          0 non-null      float64
#  11  infraAuthority     0 non-null      float64
#  12  subpopulationName  0 non-null      float64
#  13  authority          23230 non-null  object
#  14  taxonomicNotes     8180 non-null   object
# dtypes: float64(4), int64(1), object(10)
# ...

# %%
df_taxom.columns
# Out:
# Index(['internalTaxonId', 'scientificName', 'kingdomName', 'phylumName',
#        'className', 'orderName', 'familyName', 'genusName', 'speciesName',
#        'infraType', 'infraName', 'infraAuthority', 'subpopulationName',
#        'authority', 'taxonomicNotes'],
#       dtype='object')

# %%
df_taxom['className'].value_counts()
# Out:
# ACTINOPTERYGII        4109
# INSECTA               3745
# AMPHIBIA              3015
# GASTROPODA            2950
# AVES                  2530
# REPTILIA              2420
# MAMMALIA              1807
# MALACOSTRACA           686
# CHONDRICHTHYES         609
# ANTHOZOA               461
# BIVALVIA               293
# ARACHNIDA              274
# DIPLOPODA              148
# MAXILLOPODA             53
# BRANCHIOPODA            44
# CLITELLATA              39
# HEXANAUPLIA             25
# HOLOTHUROIDEA           16
# CEPHALASPIDOMORPHI      12
# OSTRACODA               11
# MYXINI                  11
# HYDROZOA                11
# CHILOPODA               10
# UDEONYCHOPHORA          10
# COLLEMBOLA               8
# CEPHALOPODA              7
# SOLENOGASTRES            3
# SARCOPTERYGII            3
# ENOPLA                   3
# MEROSTOMATA              2
# POLYPLACOPHORA           2
# ECHINOIDEA               1
# POLYCHAETA               1
# ASTEROIDEA               1
# ...

# %%
df_taxom['familyName']
# Out:
# 0            HEXANCHIDAE
# 1            GEOEMYDIDAE
# 2              GOODEIDAE
# 3        DIPLOMMATINIDAE
# 4            ICTALURIDAE
#               ...
# 23315    CERCOPITHECIDAE
# 23316            CEBIDAE
# 23317        PITHECIIDAE
# 23318     CALLITRICHIDAE
# 23319       ELEPHANTIDAE
# Name: familyName, Length: 23320, dtype: object

# %%
df_taxom['authority']
# Out:
# 0                                       (Bonnaterre, 1788)
# 1            (Boulenger in Annandale &amp; Robinson, 1903)
# 2                                          (de Buen, 1940)
# 3                                            Beddome, 1889
# 4                                             (Meek, 1904)
#                                ...
# 23315                                     (Linnaeus, 1766)
# 23316                                      (Illiger, 1815)
# 23317       (Gualda-Barros, Nascimento &amp; Amaral, 2012)
# 23318    Costa-Araújo, Silva-Jr., Boubli, Rossi, Hrbek ...
# 23319                                   (Blumenbach, 1797)
# Name: authority, Length: 23320, dtype: object

# %%
df_taxom['subpopulationName']
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#          ..
# 23315   NaN
# 23316   NaN
# 23317   NaN
# 23318   NaN
# 23319   NaN
# Name: subpopulationName, Length: 23320, dtype: float64

# %%
df_taxom.describe
# Out:
# <bound method NDFrame.describe of        internalTaxonId           scientificName kingdomName phylumName  \
# 0                10030        Hexanchus griseus    ANIMALIA   CHORDATA
# 1                10041      Heosemys annandalii    ANIMALIA   CHORDATA
# 2            132523146         Hubbsina turneri    ANIMALIA   CHORDATA
# 3                10267  Hungerfordia pelewensis    ANIMALIA   MOLLUSCA
# 4                10769      Ictalurus mexicanus    ANIMALIA   CHORDATA
# ...                ...                      ...         ...        ...
# 23315             4224  Cercopithecus nictitans    ANIMALIA   CHORDATA
# 23316           136366              Sapajus cay    ANIMALIA   CHORDATA
# 23317         70330181    Plecturocebus vieirai    ANIMALIA   CHORDATA
# 23318        210363264          Mico schneideri    ANIMALIA   CHORDATA
# 23319        181008073       Loxodonta africana    ANIMALIA   CHORDATA
#
#             className           orderName       familyName      genusName  \
# ...

# %%
# we select two columns we are saying please in column 'systems' identify all names marine and the give me the scientificName

for index, row in df_redlist.iterrows():
    if row['systems'] == 'Marine':
        print(row['scientificName'])
# Out:
# Hexanchus griseus
# Lamna nasus
# Lithognathus lithognathus
# Lutjanus cyanopterus
# Menidia conchorum
# Mictocaris halope
# Pseudobatos percellens
# Carcharhinus acronotus
# Somniosus pacificus
# Myliobatis goodei
# Mustelus norrisi
# Carcharhinus isodon
# Carcharhinus altimus
# Alopias superciliosus
# Pseudobatos lentiginosus
# Sepia apama
# Opisthoteuthis mero
# Opisthoteuthis massyae
# Cirroctopus hochbergi
# Octopus kaharoa
# Verasper variegatus
# Palinurus elephas
# Dentex angolensis
# Cheimerius matsubarai
# Stenotomus chrysops
# Chrysoblephus laticeps
# Acanthopagrus vagus
# Acanthopagrus chinshira
# Chrysoblephus cristiceps
# Polysteganus praeorbitalis
# Chrysoblephus anglicus
# Lithognathus aureti
# Cymatoceps nasutus
# Polysteganus undulosus
# Pachymetopon grande
# Rhabdosargus globiceps
# Sparodon durbanensis
# Argyrozona argyrozona
# Pagellus bogaraveo
# Dentex dentex
# Petrus rupestris
# Chrysoblephus gibbiceps
# Opisthoteuthis calypso
# Acanthurus chronixis
# ...

# %%
df_redlist
# Out:
#        assessmentId  internalTaxonId           scientificName  \
# 0            495630            10030        Hexanchus griseus
# 1            495907            10041      Heosemys annandalii
# 2            497499        132523146         Hubbsina turneri
# 3            497550            10267  Hungerfordia pelewensis
# 4            498476            10769      Ictalurus mexicanus
# ...             ...              ...                      ...
# 23315     222904443             4224  Cercopithecus nictitans
# 23316     222944655           136366              Sapajus cay
# 23317     222944989         70330181    Plecturocebus vieirai
# 23318     222945240        210363264          Mico schneideri
# 23319     223031019        181008073       Loxodonta africana
#
#              redlistCategory                     redlistCriteria  \
# 0            Near Threatened                                A2bd
# 1      Critically Endangered                            A2cd+4cd
# ...

# %%
df_redlist.columns
# Out:
# Index(['assessmentId', 'internalTaxonId', 'scientificName', 'redlistCategory',
#        'redlistCriteria', 'yearPublished', 'assessmentDate', 'criteriaVersion',
#        'language', 'rationale', 'habitat', 'threats', 'population',
#        'populationTrend', 'range', 'useTrade', 'systems',
#        'conservationActions', 'realm', 'yearLastSeen', 'possiblyExtinct',
#        'possiblyExtinctInTheWild', 'scopes'],
#       dtype='object')

# %%
df_redlist.drop([], axis=1)
