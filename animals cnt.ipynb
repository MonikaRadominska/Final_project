# %%
import pandas as pd

# %%
animals= pd.read_csv('data/monday_1_checkpoint2.csv')

# %%
seperate = pd.read_excel('data/df_ok.xlsx')

# %%
animals
# Out:
#        Unnamed: 0          scientific_name      red_list_category  \
# 0               0        Hexanchus griseus        Near Threatened
# 1               1      Heosemys annandalii  Critically Endangered
# 2               2         Hubbsina turneri  Critically Endangered
# 3               3  Hungerfordia pelewensis             Endangered
# 4               4      Ictalurus mexicanus             Vulnerable
# ...           ...                      ...                    ...
# 19075       19075  Cercopithecus nictitans        Near Threatened
# 19076       19076              Sapajus cay             Vulnerable
# 19077       19077    Plecturocebus vieirai  Critically Endangered
# 19078       19078          Mico schneideri             Endangered
# 19079       19079       Loxodonta africana             Endangered
#
#        assessment_date population_trend                   systems  \
# 0                 2019       Decreasing                    Marine
# ...

# %%
#dropping columns 
animals= animals.drop(['Unnamed: 0'], axis = 1)

animals
# Out:
#                scientific_name      red_list_category  assessment_date  \
# 0            Hexanchus griseus        Near Threatened             2019
# 1          Heosemys annandalii  Critically Endangered             2018
# 2             Hubbsina turneri  Critically Endangered             2018
# 3      Hungerfordia pelewensis             Endangered             2011
# 4          Ictalurus mexicanus             Vulnerable             2018
# ...                        ...                    ...              ...
# 19075  Cercopithecus nictitans        Near Threatened             2016
# 19076              Sapajus cay             Vulnerable             2022
# 19077    Plecturocebus vieirai  Critically Endangered             2022
# 19078          Mico schneideri             Endangered             2022
# 19079       Loxodonta africana             Endangered             2020
#
#       population_trend                   systems        region habitat  \
# ...

# %%
#dropping columns 
seperate= seperate.drop(['Unnamed: 0'], axis = 1)

seperate
# Out:
#                                          scientific_name  \
# 0      N=Aedes albopictus densovirus (isolate Boublik...
# 1                             N=Adeno-associated virus 2
# 2      N=Adeno-associated virus 2 (isolate Srivastava...
# 3                                       N=Abacion magnum
# 4                                       N=Abaeis nicippe
# ...                                                  ...
# 26694                                   N=Vetigastropoda
# 26695                                    N=Viridiplantae
# 26696                                      N=Xanthomonas
# 26697                                                NaN
# 26698  e UniProt Consortium, see https://www.uniprot....
#
#                                              common_name
# 0                                               C=AalDNV
# 1                                                C=AAV-2
# 2                                                C=AAV-2
# ...

# %%
def remove_letters(df):
    # Remove first three letters from each column
    df = df.apply(lambda x: x.str[2:])
    
    return df

# %%
new_df = remove_letters(seperate)

# %%
new_df
# Out:
#                                          scientific_name  \
# 0      Aedes albopictus densovirus (isolate Boublik/1...
# 1                               Adeno-associated virus 2
# 2      Adeno-associated virus 2 (isolate Srivastava/1...
# 3                                         Abacion magnum
# 4                                         Abaeis nicippe
# ...                                                  ...
# 26694                                     Vetigastropoda
# 26695                                      Viridiplantae
# 26696                                        Xanthomonas
# 26697                                                NaN
# 26698  UniProt Consortium, see https://www.uniprot.or...
#
#                                              common_name
# 0                                                 AalDNV
# 1                                                  AAV-2
# 2                                                  AAV-2
# ...

# %%
new_df.dropna(inplace=True)
# Out:
# C:\Users\Monika\AppData\Local\Temp\ipykernel_5020\1925939579.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df.dropna(inplace=True)

# %%
animals['animal_name'] = animals['common_name'].fillna(animals['commons'])

# %%
animals['animal_name'].value_counts()
# Out:
# Whale shark          30
# Ocean sunfish        27
# American eel         24
# Bull shark           20
# Giant manta          16
#                      ..
# Peppered chub         1
# Ouachita madtom       1
# Palezone shiner       1
# Peppered shiner       1
# Elephant, African     1
# Name: animal_name, Length: 897, dtype: int64

# %%
new_df['common_name'].value_counts()
# Out:
# Fruit fly                                             143
# Yeast                                                 120
# RV-A                                                   86
# Red alga                                               82
# Orchid                                                 77
#                                                      ...
# White grouper                                           1
# Hong Kong grouper                                       1
# Banded grouper                                          1
# Areolate grouper                                        1
# e Creative Commons Attribution (CC BY 4.0) License      1
# Name: common_name, Length: 17420, dtype: int64

# %%
new_df = new_df[new_df["common_name"].str.contains('NaN') == False]

# %%
def clean_class(x):
    if x in ['known']:
        return 'NaN'
    else:
        return x

# %%
new_df['common_name'] = list(map(clean_class, new_df['common_name']))

# %%
new_df['common_name'].isna().sum()
# Out:
# 1

# %%
animals_sci_names = pd.merge(animals, new_df, on='scientific_name', how='left')

# %%
animals_sci_names['animal_names'].value_counts()
# Out:
# Whale shark             30
# Ocean sunfish           27
# American eel            24
# Bull shark              20
# Giant manta             16
#                         ..
# Huemul, south Andean     1
# Huemul, north Andean     1
# Hog deer                 1
# Giant muntjac            1
# Elephant, African        1
# Name: animal_names, Length: 2116, dtype: int64

# %%
animals_sci_names
# Out:
#                scientific_name      red_list_category  assessment_date  \
# 0            Hexanchus griseus        Near Threatened             2019
# 1          Heosemys annandalii  Critically Endangered             2018
# 2             Hubbsina turneri  Critically Endangered             2018
# 3      Hungerfordia pelewensis             Endangered             2011
# 4          Ictalurus mexicanus             Vulnerable             2018
# ...                        ...                    ...              ...
# 19075  Cercopithecus nictitans        Near Threatened             2016
# 19076              Sapajus cay             Vulnerable             2022
# 19077    Plecturocebus vieirai  Critically Endangered             2022
# 19078          Mico schneideri             Endangered             2022
# 19079       Loxodonta africana             Endangered             2020
#
#       population_trend                   systems        region habitat  \
# ...

# %%
#dropping columns 
animals_sci_names= animals_sci_names.drop(['common_name','animal_name'], axis = 1)

animals_sci_names
# Out:
#                scientific_name      red_list_category  assessment_date  \
# 0            Hexanchus griseus        Near Threatened             2019
# 1          Heosemys annandalii  Critically Endangered             2018
# 2             Hubbsina turneri  Critically Endangered             2018
# 3      Hungerfordia pelewensis             Endangered             2011
# 4          Ictalurus mexicanus             Vulnerable             2018
# ...                        ...                    ...              ...
# 19075  Cercopithecus nictitans        Near Threatened             2016
# 19076              Sapajus cay             Vulnerable             2022
# 19077    Plecturocebus vieirai  Critically Endangered             2022
# 19078          Mico schneideri             Endangered             2022
# 19079       Loxodonta africana             Endangered             2020
#
#       population_trend                   systems        region habitat  \
# ...

# %%
animals_sci_names['animal_names'].isna().sum()
# Out:
# 16333

# %%
animals_sci_names

# %%
animal_names

# %%
animals_sci_names['animal_names'] = animals_sci_names['animal_name'].fillna(animals_sci_names['common_name'])

# %%
animals['country_state'].value_counts()
# Out:
# BR                                 298
# USA                                269
# CO                                 135
# AR                                  98
# CRI                                 89
#                                   ...
# U.S.A. (IA, IL, MN, MO, NE, WI)      1
# China (Tibet), India                 1
# Taiwan                               1
# Sri Lanka (=Ceylon)                  1
# Africa                               1
# Name: country_state, Length: 313, dtype: int64

# %%
countries = pd.read_excel('country_state.xlsx')

# %%
def rename_columns(x):
    x.rename(columns={'Scientific Name':'scientific_name','Inverted Common Name':'common_name'}, inplace=True )
    return x

# %%
animals.to_csv('sundayfunday_mon.csv')

# %%
animals_countries = pd.merge(animals, countries, on='country_state', how='left')

# %%
animals_countries['latitude'].value_counts()
# Out:
# -0.789275     60
# -18.766947    40
#  37.090240    21
# -25.274398    18
#  35.861660    15
#               ..
#  14.497401     1
#  8.537981      1
# -9.645710      1
#  6.428055      1
#  56.263920     1
# Name: latitude, Length: 63, dtype: int64

# %%
animals_countries
# Out:
#                scientific_name      red_list_category  assessment_date  \
# 0            Hexanchus griseus        Near Threatened             2019
# 1          Heosemys annandalii  Critically Endangered             2018
# 2             Hubbsina turneri  Critically Endangered             2018
# 3      Hungerfordia pelewensis             Endangered             2011
# 4          Ictalurus mexicanus             Vulnerable             2018
# ...                        ...                    ...              ...
# 19075  Cercopithecus nictitans        Near Threatened             2016
# 19076              Sapajus cay             Vulnerable             2022
# 19077    Plecturocebus vieirai  Critically Endangered             2022
# 19078          Mico schneideri             Endangered             2022
# 19079       Loxodonta africana             Endangered             2020
#
#       population_trend                   systems        region habitat  \
# ...

# %%
states = pd.read_excel('states.xlsx')

# %%
states
# Out:
#    country_state  usa_state_latitude  usa_state_longitude
# 0             AK           63.588753          -154.493062
# 1             AL           32.318231           -86.902298
# 2             AR           35.201050           -91.831833
# 3             AZ           34.048928          -111.093731
# 4             CA           36.778261          -119.417932
# 5             CO           39.550051          -105.782067
# 6             CT           41.603221           -73.087749
# 7             DC           38.905985           -77.033418
# 8             DE           38.910832           -75.527670
# 9             FL           27.664827           -81.515754
# 10            GA           32.157435           -82.907123
# 11            HI           19.898682          -155.665857
# 12            IA           41.878003           -93.097702
# 13            ID           44.068202          -114.742041
# 14            IL           40.633125           -89.398528
# ...

# %%
animals_countries_states = pd.merge(animals_countries, states, on='country_state', how='left')

# %%
animals_countries_states['long'].value_counts()
# Out:
#  113.921327    60
#  46.869107     40
# -95.712891     21
#  133.775136    18
#  104.195397    15
#                ..
# -77.396280      1
# -80.566956      1
#  14.550072      1
#  32.290275      1
#  9.501785       1
# Name: long, Length: 64, dtype: int64

# %%
animals_countries_states['lat'] = animals_countries_states['latitude'].fillna(animals_countries_states['usa_state_latitude'])

# %%
animals_countries_states['lat'].isna().sum()
# Out:
# 18757

# %%
animals_countries_states['long'] = animals_countries_states['longitude'].fillna(animals_countries_states['usa_state_longitude'])

# %%
animals_countries_states['long'].isna().sum()
# Out:
# 18757

# %%
animals_countries_states
# Out:
#                scientific_name      red_list_category  assessment_date  \
# 0            Hexanchus griseus        Near Threatened             2019
# 1          Heosemys annandalii  Critically Endangered             2018
# 2             Hubbsina turneri  Critically Endangered             2018
# 3      Hungerfordia pelewensis             Endangered             2011
# 4          Ictalurus mexicanus             Vulnerable             2018
# ...                        ...                    ...              ...
# 19075  Cercopithecus nictitans        Near Threatened             2016
# 19076              Sapajus cay             Vulnerable             2022
# 19077    Plecturocebus vieirai  Critically Endangered             2022
# 19078          Mico schneideri             Endangered             2022
# 19079       Loxodonta africana             Endangered             2020
#
#       population_trend                   systems        region habitat  \
# ...

# %%
#dropping columns 
animals_countries_states = animals_countries_states.drop(['latitude', 'longitude','usa_state_latitude','usa_state_longitude'], axis = 1)

animals_countries_states
# Out:
#                scientific_name      red_list_category  assessment_date  \
# 0            Hexanchus griseus        Near Threatened             2019
# 1          Heosemys annandalii  Critically Endangered             2018
# 2             Hubbsina turneri  Critically Endangered             2018
# 3      Hungerfordia pelewensis             Endangered             2011
# 4          Ictalurus mexicanus             Vulnerable             2018
# ...                        ...                    ...              ...
# 19075  Cercopithecus nictitans        Near Threatened             2016
# 19076              Sapajus cay             Vulnerable             2022
# 19077    Plecturocebus vieirai  Critically Endangered             2022
# 19078          Mico schneideri             Endangered             2022
# 19079       Loxodonta africana             Endangered             2020
#
#       population_trend                   systems        region habitat  \
# ...

# %%
def rename_columns_df(x):
    x.rename(columns={'lat':'latitude', 'long':'longitude'}, inplace=True )
    return x

# %%
animals_countries_states = rename_columns_df(animals_countries_states)

# %%
animals_countries_states
# Out:
#                scientific_name      red_list_category  assessment_date  \
# 0            Hexanchus griseus        Near Threatened             2019
# 1          Heosemys annandalii  Critically Endangered             2018
# 2             Hubbsina turneri  Critically Endangered             2018
# 3      Hungerfordia pelewensis             Endangered             2011
# 4          Ictalurus mexicanus             Vulnerable             2018
# ...                        ...                    ...              ...
# 19075  Cercopithecus nictitans        Near Threatened             2016
# 19076              Sapajus cay             Vulnerable             2022
# 19077    Plecturocebus vieirai  Critically Endangered             2022
# 19078          Mico schneideri             Endangered             2022
# 19079       Loxodonta africana             Endangered             2020
#
#       population_trend                   systems        region habitat  \
# ...

# %%
animals_sci_names.to_csv('monday_1_checkpoint.csv')
